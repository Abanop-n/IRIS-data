# %%
from sklearn.datasets import load_iris
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Description

# %% [markdown]
# ### The Iris Dataset contains four features (length and width of sepals and petals) of 50 samples of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). These measures were used to create a linear discriminant model to classify the species.

# %% [markdown]
# #### The species classes are already encoded
#
# intoIris setosa = 0
#
# Iris virginica = 1
#
# Iris versicolor = 2

# %% [markdown]
# ## Your Task is to classify the flowers into 1 of the 3 species using the 4 feature listed below

# %%
iris_dataset = load_iris()
iris = pd.DataFrame(iris_dataset.data, columns=iris_dataset.feature_names)
iris['species'] = iris_dataset.target
iris = iris.rename(columns={'sepal length (cm)':'sepal length','sepal width (cm)':'sepal width','petal length (cm)':'petal length','petal width (cm)':'petal width'})
iris.head()
# Out:
#    sepal length  sepal width  petal length  petal width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %% [markdown]
# ## Splitting the data into train and test
# remember perform EDA only on Train data
# but if you change anything in the train set, also change it in the test set

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(iris_dataset.data,iris_dataset.target ,
                                                   test_size= 0.2,
                                                   shuffle= True, 
                                                   random_state= 123)

# %%
x_train
# Out:
# array([[7.4, 2.8, 6.1, 1.9],
#        [6. , 2.2, 5. , 1.5],
#        [4.7, 3.2, 1.6, 0.2],
#        [5.1, 3.5, 1.4, 0.2],
#        [6. , 2.2, 4. , 1. ],
#        [5. , 2.3, 3.3, 1. ],
#        [7.9, 3.8, 6.4, 2. ],
#        [5.4, 3.9, 1.7, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.8, 2.7, 3.9, 1.2],
#        [5. , 2. , 3.5, 1. ],
#        [5. , 3.2, 1.2, 0.2],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3. , 5.2, 2.3],
#        [5.8, 2.7, 5.1, 1.9],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.3, 3.4, 5.6, 2.4],
#        [5.5, 2.3, 4. , 1.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [4.4, 3. , 1.3, 0.2],
#        [6.5, 3.2, 5.1, 2. ],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.9, 3.1, 1.5, 0.1],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.1, 3. , 4.6, 1.4],
#        [5.5, 2.5, 4. , 1.3],
#        [5.7, 2.6, 3.5, 1. ],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.7, 3.1, 4.4, 1.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [4.5, 2.3, 1.3, 0.3],
#        [6.7, 3.3, 5.7, 2.1],
#        [5.7, 3. , 4.2, 1.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.8, 3.4, 1.6, 0.2],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.4, 2.9, 4.3, 1.3],
#        [7.7, 2.8, 6.7, 2. ],
#        [7.7, 2.6, 6.9, 2.3],
#        [5.1, 3.8, 1.9, 0.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [5.5, 2.4, 3.7, 1. ],
#        [5.9, 3. , 5.1, 1.8],
#        [4.8, 3. , 1.4, 0.1],
#        [7.2, 3. , 5.8, 1.6],
#        [6.3, 3.3, 4.7, 1.6],
#        [7. , 3.2, 4.7, 1.4],
#        [5. , 3. , 1.6, 0.2],
#        [6.4, 2.8, 5.6, 2.1],
#        [6.3, 2.5, 5. , 1.9],
#        [5. , 3.5, 1.6, 0.6],
#        [4.9, 3. , 1.4, 0.2],
#        [6.1, 2.8, 4. , 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [6.3, 3.3, 6. , 2.5],
#        [5.8, 4. , 1.2, 0.2],
#        [4.6, 3.4, 1.4, 0.3],
#        [5.5, 2.4, 3.8, 1.1],
#        [5. , 3.4, 1.6, 0.4],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.9, 3.1, 5.4, 2.1],
#        [4.8, 3.1, 1.6, 0.2],
#        [6.7, 2.5, 5.8, 1.8],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.7, 3.8, 1.7, 0.3],
#        [6.7, 3. , 5. , 1.7],
#        [4.6, 3.6, 1. , 0.2],
#        [5.4, 3.7, 1.5, 0.2],
#        [6.6, 2.9, 4.6, 1.3],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.6, 3. , 4.4, 1.4],
#        [5.6, 2.9, 3.6, 1.3],
#        [5.6, 2.5, 3.9, 1.1],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.5, 1.3, 0.3],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.1, 2.6, 5.6, 1.4],
#        [4.9, 3.1, 1.5, 0.2],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.6, 2.7, 4.2, 1.3],
#        [6. , 3.4, 4.5, 1.6],
#        [6.2, 2.9, 4.3, 1.3],
#        [7.1, 3. , 5.9, 2.1],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.8, 2.6, 4. , 1.2],
#        [5.7, 2.8, 4.1, 1.3],
#        [7.6, 3. , 6.6, 2.1],
#        [5. , 3.4, 1.5, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5.9, 3. , 4.2, 1.5],
#        [6.9, 3.2, 5.7, 2.3],
#        [6.4, 3.1, 5.5, 1.8],
#        [7.2, 3.2, 6. , 1.8],
#        [6.5, 3. , 5.2, 2. ],
#        [5.1, 3.4, 1.5, 0.2],
#        [5.4, 3. , 4.5, 1.5],
#        [4.7, 3.2, 1.3, 0.2],
#        [5.8, 2.7, 4.1, 1. ],
#        [5.7, 2.8, 4.5, 1.3],
#        [5. , 3.3, 1.4, 0.2],
#        [6.2, 2.2, 4.5, 1.5],
#        [6.7, 3.1, 5.6, 2.4],
#        [6. , 2.9, 4.5, 1.5],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.4, 2.7, 5.3, 1.9],
#        [5.2, 4.1, 1.5, 0.1],
#        [6.1, 2.8, 4.7, 1.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.7, 2.5, 5. , 2. ],
#        [5.7, 2.9, 4.2, 1.3],
#        [4.9, 2.4, 3.3, 1. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [4.9, 2.5, 4.5, 1.7],
#        [6. , 2.7, 5.1, 1.6],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.1, 2.5, 3. , 1.1],
#        [5.6, 3. , 4.5, 1.5],
#        [6.2, 2.8, 4.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5]])

# %%
x_test
# Out:
# array([[6.3, 2.5, 4.9, 1.5],
#        [6.8, 3. , 5.5, 2.1],
#        [6.4, 2.8, 5.6, 2.2],
#        [5.6, 3. , 4.1, 1.3],
#        [4.9, 3.6, 1.4, 0.1],
#        [6. , 3. , 4.8, 1.8],
#        [6.3, 2.3, 4.4, 1.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.5, 4.2, 1.4, 0.2],
#        [5.2, 2.7, 3.9, 1.4],
#        [6.5, 3. , 5.5, 1.8],
#        [7.7, 3. , 6.1, 2.3],
#        [6.5, 3. , 5.8, 2.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.3, 3. , 1.1, 0.1],
#        [6.1, 2.9, 4.7, 1.4],
#        [4.8, 3. , 1.4, 0.3],
#        [5.2, 3.4, 1.4, 0.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [6.1, 3. , 4.9, 1.8],
#        [5.1, 3.8, 1.6, 0.2],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.6, 2.8, 4.9, 2. ],
#        [7.7, 3.8, 6.7, 2.2],
#        [5. , 3.6, 1.4, 0.2]])

# %%
iris['species'].unique()
# Out:
# array([0, 1, 2])

# %%
iris.isnull().sum()
# Out:
# sepal length    0
# sepal width     0
# petal length    0
# petal width     0
# species         0
# dtype: int64

# %% [markdown]
# # Your Assignment starts here

# %% [markdown]
# ## First make some EDA
# you can do any form of EDA, I want at least 4 forms of EDA (ask 4 questions about the data and answer them)

# %% [markdown]
# what is the correlation between features and target?

# %%
sns.heatmap(iris.corr(),  annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# petal length and width are the most effictive on detect flower type

# %% [markdown]
# Is there outlires and what is 5-numbers summury?

# %%
iris.describe()
# Out:
#        sepal length  sepal width  petal length  petal width     species
# count    150.000000   150.000000    150.000000   150.000000  150.000000
# mean       5.843333     3.057333      3.758000     1.199333    1.000000
# std        0.828066     0.435866      1.765298     0.762238    0.819232
# min        4.300000     2.000000      1.000000     0.100000    0.000000
# 25%        5.100000     2.800000      1.600000     0.300000    0.000000
# 50%        5.800000     3.000000      4.350000     1.300000    1.000000
# 75%        6.400000     3.300000      5.100000     1.800000    2.000000
# max        7.900000     4.400000      6.900000     2.500000    2.000000

# %%
plt.figure(figsize=(8,6))
plt.boxplot(iris['species'], flierprops=dict(markerfacecolor='b', marker='o'), showfliers=True, vert=True)
plt.title('species Box Plot', size=16)
plt.show()

# %% [markdown]
# what is the distrbution of species in features data?

# %%
sns.pairplot(iris, hue="species", size=3)
# Out:
# C:\Users\popan\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# type 0 has both low petal length and width
# type 1 has both average petal length and width
# type 2 has both high petal length and width.
# Sepal width for type 0 is high and length is low.
# type 1 have average values for for sepal dimensions.
# type 2 has small width but large sepal length

# %%
plt.figure(figsize=(15,10))
ax = sns.distplot(iris['species'], kde=True)
ax.set_title('Distplot of Price', fontsize=14)
# Out:
# C:\Users\popan\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Distplot of Price')

# %% [markdown]
# # Model Training

# %% [markdown]
# ## Use KNN classifier to classify the species of the flower
# Check this documentation to know how to use it
# https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html

# %% [markdown]
# first Import the classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# define the classifier and how many nearest neighbors to use (the value of K)

# %%
knn = KNeighborsClassifier(2)

# %% [markdown]
# train the model on train data

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %% [markdown]
# use the model to predict on the train data

# %%
y_train_knn=knn.predict(x_train)

# %% [markdown]
# use the model to predict on the test data

# %%
y_pred = knn.predict(x_test)

# %% [markdown]
# use accuracy_score to measure the model's performance
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html

# %%
from sklearn.metrics import accuracy_score

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9

# %% [markdown]
# ## Repeat all the training steps with different value of K
# you can repeat it as much as you want

# %%
knn = KNeighborsClassifier(3)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_train_knn=knn.predict(x_train)

# %%
y_pred = knn.predict(x_test)

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9666666666666667

# %%
knn = KNeighborsClassifier(10)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
y_train_knn=knn.predict(x_train)

# %%
y_pred = knn.predict(x_test)

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9333333333333333
